# %%
import pandas as pd

# %%
df = pd.read_excel("data_generated-01.xlsx")

# %%
df = df[['item', 'sdate', 'edate', 'days', 'log_days',
       'bags_count', 'total_weight_in', 'total_weight_out', 'loss',
       'loss/bag', 'charge_per_kg_per_day', 'labour_charge',
       'weighted _charging', 'current_charge', 'intrest_charging']]

# %%
import matplotlib.pyplot as plt

# Given data
crops = ['Chana', 'Wheat', 'Soyabean']
prices = [1.83, 1.64, 1.74]

# Creating a bar chart
plt.bar(crops, prices, color='black')

# Adding labels and title
plt.xlabel('Crops')
plt.ylabel('Average of loss-per-bag(kg)')
plt.title('Crop wise Loss in weight')

# Displaying the bar chart
plt.savefig("bar-01.png")
